# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('board2.csv')
df['Average'] = df[['Math', 'Electronics']].mean(axis=1)
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication  Average
# 0              78     73.5
# 1              52     63.5
# 2              57     78.5
# 3              68     61.5
# 4              88     72.5
# 5              83     66.5
# 6              48     63.0
# 7              53     65.0
# 8              42     43.0
# 9              44     82.0
# 10             67     52.0
# 11             64     78.0
# 12             43     61.5
# 13             73     80.0
# 14             86     55.0
# 15             81     70.5
# 16             45     80.0
# 17             52     60.5
# 18             71     71.0
# 19             85     59.5
# 20             72     67.0
# 21             58     51.5
# 22             47     77.0
# 23             41     65.0
# 24             42     82.5
# 25             62     59.0
# 26             86     58.5
# 27             53     69.0
# 28             62     60.5
# 29             56     79.5

# %% [markdown]
# # A. VISAYAS COMMUNICATION DATAFRAME

# %%
Filtered = df[(df['Hometown'] == 'Visayas') & (df['Track'] == 'Communication')]
Viscomm = Filtered[['Name','Gender', 'Math', 'Electronics', 'Average' ]]
Viscomm
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56     52.0
# 11  S12    Male    89           67     78.0
# 17  S18    Male    81           40     60.5
# 21  S22  Female    64           39     51.5
# 27  S28    Male    85           53     69.0

# %%
print("\nNumber of rows:", len(Viscomm))
# Out:
# Number of rows: 5

# %% [markdown]
# # B. VISAYAS FEMALE DATAFRAME

# %%
Filtered = df[(df['Hometown'] == 'Visayas') & (df['Track'] == 'Communication')]
Viscomm = Filtered[['Name','Gender', 'Math', 'Electronics', 'Average', 'GEAS', 'Track']]
Viscomm
# Out:
#    Name  Gender  Math  Electronics  Average  GEAS          Track
# 10  S11  Female    48           56     52.0    48  Communication
# 11  S12    Male    89           67     78.0    84  Communication
# 17  S18    Male    81           40     60.5    81  Communication
# 21  S22  Female    64           39     51.5    89  Communication
# 27  S28    Male    85           53     69.0    80  Communication

# %%
FViscomm = Viscomm[(Viscomm['Gender'] == 'Female')]
VisFemale = FViscomm[['Name','Track', 'GEAS', 'Electronics', 'Average' ]]
VisFemale
# Out:
#    Name          Track  GEAS  Electronics  Average
# 10  S11  Communication    48           56     52.0
# 21  S22  Communication    89           39     51.5

# %%
VisFemale.loc[(VisFemale['Average']>60)]
# Out:
# Empty DataFrame
# Columns: [Name, Track, GEAS, Electronics, Average]
# Index: []

# %% [markdown]
# # C. CATEGORY-AVERAGE VISUALIZATION

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['Average'] = df[['Math', 'Electronics']].mean(axis=1)

# %% [markdown]
# ## a. For each feature, compute the mean of Average for every category using Pandas.

# %%
Trackmean = df.groupby('Track')['Average'].mean()
Gendermean = df.groupby('Gender')['Average'].mean()
Hometownmean = df.groupby('Hometown')['Average'].mean()

# %% [markdown]
# ## b. Display the three summary tables.

# %%
Trackmean
# Out:
# Track
# Communication       65.95
# Instrumentation     66.05
# Microelectronics    68.65
# Name: Average, dtype: float64

# %%
Gendermean
# Out:
# Gender
# Female    64.833333
# Male      68.933333
# Name: Average, dtype: float64

# %%
Hometownmean
# Out:
# Hometown
# Luzon       69.916667
# Mindanao    68.428571
# Visayas     62.590909
# Name: Average, dtype: float64

# %% [markdown]
# ## c. Create one figure containing three bar charts: mean Average by Track, by Gender, and by Hometown.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

Trackmean.plot(kind='bar', ax=axes[0], color='skyblue', edgecolor='black')
axes[0].set_title('Mean Average by Track')
axes[0].set_ylabel('Average Score')

Gendermean.plot(kind='bar', ax=axes[1], color='lightgreen', edgecolor='black')
axes[1].set_title('Mean Average by Gender')
axes[1].set_xlabel('Gender')

Hometownmean.plot(kind='bar', ax=axes[2], color='salmon', edgecolor='black')
axes[2].set_title('Mean Average by Hometown')
axes[2].set_xlabel('Hometown')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## d. Below the figure, write three concise statements identifying the category with the highest sample mean for each feature.

# %%
print("Interpretation:")
print(f"- Track with highest mean: {Trackmean.idxmax()} ({Trackmean.max():.2f})")
print(f"- Gender with highest mean: {Gendermean.idxmax()} ({Gendermean.max():.2f})")
print(f"- Hometown with highest mean: {Hometownmean.idxmax()} ({Hometownmean.max():.2f})")
# Out:
# Interpretation:
# - Track with highest mean: Microelectronics (68.65)
# - Gender with highest mean: Male (68.93)
# - Hometown with highest mean: Luzon (69.92)
